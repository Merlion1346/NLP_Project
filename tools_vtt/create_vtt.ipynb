# %%
import yt_dlp

# %%
ydl_opts = {
    'writesubtitles': True,
    'writeautomaticsub': True,
    'subtitleslangs': ['ko'],
    'skip_download': True,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=1SHBvDsdbMs'])
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1SHBvDsdbMs
# [youtube] 1SHBvDsdbMs: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 1SHBvDsdbMs: Downloading android vr player API JSON
# [info] 1SHBvDsdbMs: Downloading subtitles: ko
# WARNING: ffmpeg not found. The downloaded format may not be the best available. Installing ffmpeg is strongly recommended: https://github.com/yt-dlp/yt-dlp#dependencies
# [info] 1SHBvDsdbMs: Downloading 1 format(s): 18
# [info] Writing video subtitles to: [풀영상] 뉴스9 ： 지방선거 한 달 앞, 본격 경쟁 돌입…주요 격전지와 관전 포인트는？ – 2026년 5월 3일(일) ⧸ KBS [1SHBvDsdbMs].ko.vtt
# ...
